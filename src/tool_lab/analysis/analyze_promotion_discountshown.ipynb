# %%
from __future__ import annotations

from pathlib import Path
from typing import Any
import json

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import yaml

from pydantic import BaseModel
from typing import Literal
from openai import OpenAI

def load_events(results_file: str | Path) -> pd.DataFrame:
    """Load events.jsonl file into a single DataFrame."""
    path = Path(results_file)
    frames = []
    rows = [json.loads(line) for line in path.read_text(encoding="utf-8").splitlines() if line]
    if rows:
        frames.append(pd.DataFrame(rows))
    if not frames:
        return pd.DataFrame()
    df = pd.concat(frames, ignore_index=True)
    return df

def load_all_events(results_files: list) -> pd.DataFrame:
    all_dfs = []
    for rf in results_files:
        temp_df = load_events(rf)
        all_dfs.append(temp_df)
    return pd.concat(all_dfs, ignore_index=True)


def _load_analysis_config(config: dict[str, Any] | str | Path | None) -> dict[str, Any] | None:
    if config is None or isinstance(config, dict):
        return config
    path = Path(config)
    text = path.read_text(encoding="utf-8")
    if path.suffix.lower() == ".json":
        return json.loads(text)
    return yaml.safe_load(text)


exp_name = 'promotion-test'

def get_data(exp_name):
    results_dir = Path('/home/dw/github/toollab/results/')/exp_name
    results_files = list(results_dir.glob('*-events.jsonl'))
    config_files = list(results_dir.glob('*-config.json'))
    config_file = config_files[0] if config_files else None
    config = _load_analysis_config(config_file)
    metadata_columns = list(config['metadata'].keys())
    # print('metadata_columns', metadata_columns)

    df_raw = load_all_events(results_files)
    df = df_raw.copy().sort_values(['session_name', 'step_index'])
    meta_df = df['meta'].dropna().apply(pd.Series)
    meta_df = meta_df.add_prefix('meta_')
    if not meta_df.empty:
        df = df.join(meta_df)

    meta_cols = df.filter(like='meta_').columns
    df[meta_cols] = df.groupby('session_name')[meta_cols].ffill()
    return df, config

df, config = get_data(exp_name)
# print(f"{len(df)} events across {df['session_name'].nunique()} sessions")
# print(df[['option_count', 'design']])
print(df.columns)
print(df.shape)

print("\nNumber of sessions per condition:")

# df.groupby(['model_name', *metadata_columns])['session_name'].nunique().reset_index()

gemini_flash_lite = df[(df['model_name']=='gemini-3.1-flash-lite-preview')&(df['kind']=='tool')]
# gemini_flash_lite[['budget_type', 'budget_max','choice','step_index','option_id', 'attribute_id', 'value', 'transition']]
# Out:
# Index(['session_name', 'experiment_name', 'provider', 'model_name',
#        'forced_choice', 'choice', 'budget_type', 'budget_max',
#        'cumulative_cost_usd', 'budget_remaining_usd', 'cumulative_cost_tools',
#        'budget_remaining_tools', 'cumulative_cost_tokens',
#        'budget_remaining_tokens', 'cumulative_cost_points',
#        'budget_remaining_points', 'option_count', 'option_mapping',
#        'started_at', 'finished_at', 'step_index', 'kind', 'content',
#        'reasoning', 'input_tokens', 'output_tokens', 'input_cost',
#        'output_cost', 'tool_cost', 'point_cost', 'tool_calls', 'finish_reason',
#        'meta', 'tool_name', 'tool_call_id', 'option_id', 'attribute_id',
#        'result', 'is_revisit', 'transition', 'option_label',
#        'meta_model_version'],
#       dtype='str')
# (896, 42)
#
# Number of sessions per condition:

# %% [markdown]
# ### Transitions

# %%
gemini_flash = df[(df['model_name']=='gemini-3-flash-preview')&(df['kind']=='tool')]
# gemini_lite.columns
gemini_flash[['budget_type', 'budget_max','choice','step_index','option_id', 'attribute_id', 'value', 'transition']]
# Out:
#    budget_type  budget_max    choice  step_index option_id   attribute_id  \
# 1          NaN         NaN  coffee_a           2  coffee_a  price_dollars
# 3          NaN         NaN  coffee_a           4  coffee_b  price_dollars
# 5          NaN         NaN  coffee_a           6  coffee_a      weight_oz
# 7          NaN         NaN  coffee_a           8  coffee_b      weight_oz
# 9          NaN         NaN  coffee_a          10  coffee_a    price_cents
# 11         NaN         NaN  coffee_a          12  coffee_a            NaN
# 13         NaN         NaN  coffee_b           2  coffee_a  price_dollars
# 15         NaN         NaN  coffee_b           4  coffee_a    price_cents
# 17         NaN         NaN  coffee_b           6  coffee_a      weight_oz
# 19         NaN         NaN  coffee_b           8  coffee_b  price_dollars
# 21         NaN         NaN  coffee_b          10  coffee_b      weight_oz
# 23         NaN         NaN  coffee_b          12  coffee_b            NaN
# 25      tokens      5000.0  coffee_a           2  coffee_a  price_dollars
# 27      tokens      5000.0  coffee_a           4  coffee_a    price_cents
# 29      tokens      5000.0  coffee_a           6  coffee_a      weight_oz
# 32      tokens      5000.0  coffee_a           9  coffee_a            NaN
# 34       tools         1.0  coffee_a           2  coffee_a  price_dollars
# 36       tools         1.0  coffee_a           4  coffee_a            NaN
# 38       tools         5.0  coffee_a           2  coffee_a  price_dollars
# 40       tools         5.0  coffee_a           4  coffee_a      weight_oz
# 42       tools         5.0  coffee_a           6  coffee_b  price_dollars
# 44       tools         5.0  coffee_a           8  coffee_b      weight_oz
# 46       tools         5.0  coffee_a          10  coffee_a    price_cents
# 48       tools         5.0  coffee_a          12  coffee_a            NaN
#
#       value   transition
# 1       $12        first
# 3       $13    attribute
# 5   13.0 oz     diagonal
# 7   13.9 oz    attribute
# 9       .99     diagonal
# 11      NaN          NaN
# 13      $12        first
# 15      .99  alternative
# 17  13.0 oz  alternative
# 19      $13     diagonal
# 21  13.9 oz  alternative
# 23      NaN          NaN
# 25      $12        first
# 27      .99  alternative
# 29  13.0 oz  alternative
# 32      NaN          NaN
# 34      $12        first
# 36      NaN          NaN
# 38      $12        first
# 40  13.0 oz  alternative
# 42      $13     diagonal
# 44  13.9 oz  alternative
# 46      .99     diagonal
# 48      NaN          NaN

# %%
gpt = df[(df['model_name'].str.contains('gpt'))&(df['kind']=='tool')]
# gemini_lite.columns
gpt[['model_name', 'budget_max','choice','step_index','option_id', 'attribute_id', 'value', 'transition']]
# Out:
#        model_name  budget_max    choice  step_index option_id   attribute_id  \
# 115  gpt-5.4-mini         5.0  coffee_b           2  coffee_a  price_dollars
# 117  gpt-5.4-mini         5.0  coffee_b           4  coffee_a    price_cents
# 119  gpt-5.4-mini         5.0  coffee_b           6  coffee_a      weight_oz
# 121  gpt-5.4-mini         5.0  coffee_b           8  coffee_b  price_dollars
# 123  gpt-5.4-mini         5.0  coffee_b          10  coffee_b      weight_oz
# 125  gpt-5.4-mini         5.0  coffee_b          12  coffee_b            NaN
# 127       gpt-5.4         5.0  coffee_b           2  coffee_a  price_dollars
# 129       gpt-5.4         5.0  coffee_b           4  coffee_a    price_cents
# 131       gpt-5.4         5.0  coffee_b           6  coffee_a      weight_oz
# 133       gpt-5.4         5.0  coffee_b           8  coffee_b  price_dollars
# 135       gpt-5.4         5.0  coffee_b          10  coffee_b      weight_oz
# 137       gpt-5.4         5.0  coffee_b          12  coffee_b            NaN
# 139  gpt-5.4-nano         5.0  coffee_a           2  coffee_a  price_dollars
# 141  gpt-5.4-nano         5.0  coffee_a           4  coffee_a    price_cents
# 143  gpt-5.4-nano         5.0  coffee_a           6  coffee_a      weight_oz
# 145  gpt-5.4-nano         5.0  coffee_a           8  coffee_b  price_dollars
# 147  gpt-5.4-nano         5.0  coffee_a          10  coffee_b    price_cents
# 149  gpt-5.4-nano         5.0  coffee_a          12  coffee_a            NaN
# 151  gpt-5.4-nano         5.0  coffee_b           2  coffee_a  price_dollars
# 153  gpt-5.4-nano         5.0  coffee_b           4  coffee_a    price_cents
# 155  gpt-5.4-nano         5.0  coffee_b           6  coffee_a      weight_oz
# 157  gpt-5.4-nano         5.0  coffee_b           8  coffee_b  price_dollars
# 159  gpt-5.4-nano         5.0  coffee_b          10  coffee_b    price_cents
# 161  gpt-5.4-nano         5.0  coffee_b          12  coffee_b            NaN
# 163  gpt-5.4-nano         5.0  coffee_a           2  coffee_a  price_dollars
# 165  gpt-5.4-nano         5.0  coffee_a           4  coffee_a    price_cents
# 167  gpt-5.4-nano         5.0  coffee_a           6  coffee_a      weight_oz
# 169  gpt-5.4-nano         5.0  coffee_a           8  coffee_b  price_dollars
# 171  gpt-5.4-nano         5.0  coffee_a          10  coffee_b    price_cents
# 173  gpt-5.4-nano         5.0  coffee_a          12  coffee_a            NaN
#
#        value   transition
# 115      $12        first
# 117      .99  alternative
# 119  13.0 oz  alternative
# 121      $13     diagonal
# 123  13.9 oz  alternative
# 125      NaN          NaN
# 127      $12        first
# 129      .99  alternative
# 131  13.0 oz  alternative
# 133      $13     diagonal
# 135  13.9 oz  alternative
# 137      NaN          NaN
# 139      $12        first
# 141      .99  alternative
# 143  13.0 oz  alternative
# 145      $13     diagonal
# 147      .00  alternative
# 149      NaN          NaN
# 151      $12        first
# 153      .99  alternative
# 155  13.0 oz  alternative
# 157      $13     diagonal
# 159      .00  alternative
# 161      NaN          NaN
# 163      $12        first
# 165      .99  alternative
# 167  13.0 oz  alternative
# 169      $13     diagonal
# 171      .00  alternative
# 173      NaN          NaN

# %%
df.columns
# Out:
# Index(['session_name', 'experiment_name', 'provider', 'model_name',
#        'forced_choice', 'choice', 'cumulative_cost_usd',
#        'budget_remaining_usd', 'cumulative_cost_tools',
#        'budget_remaining_tools', 'option_count', 'seed', 'started_at',
#        'finished_at', 'step_index', 'kind', 'content', 'reasoning',
#        'input_tokens', 'output_tokens', 'input_cost', 'output_cost',
#        'tool_cost', 'tool_calls', 'finish_reason', 'tool_name', 'tool_call_id',
#        'option_id', 'attribute_id', 'value', 'turn_cost_tools', 'is_revisit',
#        'transition', 'option_label', 'budget_type', 'budget_max',
#        'budget_remaining_tokens', 'cumulative_cost_tokens', 'turn_cost_tokens',
#        'meta', 'meta_gpt-5.4-mini-2026-03-17', 'meta_none',
#        'meta_gpt-5.4-2026-03-05', 'meta_gpt-5.4-nano-2026-03-17',
#        'meta_claude-sonnet-4-6', 'meta_thinking', 'meta_effort',
#        'meta_model_version'],
#       dtype='str')

# %%
df
# Out:
#                session_name experiment_name  provider  \
# 0    20260409T201335248464Z      left-digit    google
# 1    20260409T201335248464Z      left-digit    google
# 2    20260409T201335248464Z      left-digit    google
# 3    20260409T201335248464Z      left-digit    google
# 4    20260409T201335248464Z      left-digit    google
# ..                      ...             ...       ...
# 225  20260410T163414801115Z      left-digit  llamacpp
# 226  20260410T163414801115Z      left-digit  llamacpp
# 227  20260410T163414801115Z      left-digit  llamacpp
# 228  20260410T163414801115Z      left-digit  llamacpp
# 229  20260410T163414801115Z      left-digit  llamacpp
#
#                              model_name  forced_choice    choice  \
# 0                gemini-3-flash-preview          False  coffee_a
# 1                gemini-3-flash-preview          False  coffee_a
# 2                gemini-3-flash-preview          False  coffee_a
# 3                gemini-3-flash-preview          False  coffee_a
# 4                gemini-3-flash-preview          False  coffee_a
# ..                                  ...            ...       ...
# 225  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf          False  coffee_b
# 226  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf          False  coffee_b
# 227  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf          False  coffee_b
# 228  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf          False  coffee_b
# 229  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf          False  coffee_b
#
#      cumulative_cost_usd  budget_remaining_usd  cumulative_cost_tools  \
# 0               0.000309             -0.000309                      1
# 1               0.000309             -0.000309                      1
# 2               0.001107             -0.001107                      2
# 3               0.001107             -0.001107                      2
# 4               0.002083             -0.002083                      3
# ..                   ...                   ...                    ...
# 225             0.000000              0.000000                      4
# 226             0.000000              0.000000                      5
# 227             0.000000              0.000000                      5
# 228             0.000000              0.000000                      5
# 229             0.000000              0.000000                      5
#
#      budget_remaining_tools  ...  turn_cost_tokens  \
# 0                         4  ...               NaN
# 1                         4  ...               NaN
# 2                         3  ...               NaN
# 3                         3  ...               NaN
# 4                         2  ...               NaN
# ..                      ...  ...               ...
# 225                       1  ...               NaN
# 226                       0  ...               NaN
# 227                       0  ...               NaN
# 228                       0  ...               NaN
# 229                       0  ...               NaN
#
#                                                   meta  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 225                                                NaN
# 226  {'model_version': 'gemma-4-26B-A4B-it-UD-Q4_K_...
# 227                                                NaN
# 228  {'model_version': 'gemma-4-26B-A4B-it-UD-Q4_K_...
# 229                                                NaN
#
#     meta_gpt-5.4-mini-2026-03-17 meta_none  meta_gpt-5.4-2026-03-05  \
# 0                            NaN       NaN                      NaN
# 1                            NaN       NaN                      NaN
# 2                            NaN       NaN                      NaN
# 3                            NaN       NaN                      NaN
# 4                            NaN       NaN                      NaN
# ..                           ...       ...                      ...
# 225                          NaN       NaN                      NaN
# 226                          NaN       NaN                      NaN
# 227                          NaN       NaN                      NaN
# 228                          NaN       NaN                      NaN
# 229                          NaN       NaN                      NaN
#
#     meta_gpt-5.4-nano-2026-03-17 meta_claude-sonnet-4-6 meta_thinking  \
# 0                            NaN                    NaN           NaN
# 1                            NaN                    NaN           NaN
# 2                            NaN                    NaN           NaN
# 3                            NaN                    NaN           NaN
# 4                            NaN                    NaN           NaN
# ..                           ...                    ...           ...
# 225                          NaN                    NaN           NaN
# 226                          NaN                    NaN           NaN
# 227                          NaN                    NaN           NaN
# 228                          NaN                    NaN           NaN
# 229                          NaN                    NaN           NaN
#
#      meta_effort                  meta_model_version
# 0            NaN                                 NaN
# 1            NaN                                 NaN
# 2            NaN                                 NaN
# 3            NaN                                 NaN
# 4            NaN                                 NaN
# ..           ...                                 ...
# 225          NaN  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf
# 226          NaN  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf
# 227          NaN  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf
# 228          NaN  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf
# 229          NaN  gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf
#
# [230 rows x 48 columns]

# %%
anthropic = df[(df['provider'].str.contains('anthropic'))&(df['kind']=='tool')]
# gemini_lite.columns
anthropic[['model_name', 'meta_thinking', 'meta_effort', 'budget_max','choice','step_index','option_id', 'attribute_id', 'value', 'transition']]
# Out:
#             model_name meta_thinking meta_effort  budget_max    choice  \
# 175  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 177  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 179  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 181  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 183  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 185  claude-sonnet-4-6           NaN         NaN         5.0  coffee_b
# 187  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 189  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 191  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 193  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 195  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 197  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 199  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 201  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 203  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 205  claude-sonnet-4-6           NaN         NaN         5.0  coffee_a
# 207  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
# 209  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
# 211  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
# 213  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
# 215  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
# 217  claude-sonnet-4-6      adaptive         low         5.0  coffee_b
#
#      step_index option_id   attribute_id    value   transition
# 175           2  coffee_a  price_dollars      $12        first
# 177           4  coffee_a    price_cents      .99  alternative
# 179           6  coffee_a      weight_oz  13.0 oz  alternative
# 181           8  coffee_b  price_dollars      $13     diagonal
# 183          10  coffee_b      weight_oz  13.9 oz  alternative
# 185          12  coffee_b            NaN      NaN          NaN
# 187           2  coffee_a  price_dollars      $12        first
# 189           4  coffee_b  price_dollars      $13    attribute
# 191           6  coffee_a      weight_oz  13.0 oz     diagonal
# 193           8  coffee_b      weight_oz  13.9 oz    attribute
# 195          10  coffee_a            NaN      NaN          NaN
# 197           2  coffee_a  price_dollars      $12        first
# 199           4  coffee_b  price_dollars      $13    attribute
# 201           6  coffee_a      weight_oz  13.0 oz     diagonal
# 203           8  coffee_b      weight_oz  13.9 oz    attribute
# 205          10  coffee_a            NaN      NaN          NaN
# 207           2  coffee_a  price_dollars      $12        first
# 209           4  coffee_a    price_cents      .99  alternative
# 211           6  coffee_a      weight_oz  13.0 oz  alternative
# 213           8  coffee_b  price_dollars      $13     diagonal
# 215          10  coffee_b      weight_oz  13.9 oz  alternative
# 217          12  coffee_b            NaN      NaN          NaN

# %%
scores = {opt['id']:opt['base_score'] for opt in config['options']}
scores
# Out:
# {'coffee_a': 1.00077, 'coffee_b': 1.06923}

# %%
# df['budget_type']

# %%
session_choices = df.groupby(['model_name','session_name'])['choice'].last().reset_index()
session_choices['score'] = session_choices['choice'].map(scores)
session_choices
# Out:
#                        model_name            session_name    choice    score
# 0          gemini-3-flash-preview  20260409T201335248464Z  coffee_a  1.00077
# 1          gemini-3-flash-preview  20260409T202110975586Z  coffee_b  1.06923
# 2          gemini-3-flash-preview  20260409T213551363719Z  coffee_a  1.00077
# 3          gemini-3-flash-preview  20260409T224320378210Z  coffee_a  1.00077
# 4   gemini-3.1-flash-lite-preview  20260409T205849239956Z  coffee_a  1.00077
# 5   gemini-3.1-flash-lite-preview  20260409T205948438333Z  coffee_a  1.00077
# 6   gemini-3.1-flash-lite-preview  20260409T212306149951Z  coffee_a  1.00077
# 7   gemini-3.1-flash-lite-preview  20260409T212652870379Z  coffee_a  1.00077
# 8   gemini-3.1-flash-lite-preview  20260409T213049600406Z  coffee_b  1.06923
# 9   gemini-3.1-flash-lite-preview  20260409T213418124240Z  coffee_a  1.00077
# 10                   gpt-5.4-mini  20260409T233724736954Z  coffee_b  1.06923

# %%
(df[(df['choice']=='coffee_b')&(df['tool_name']=='inspect_cell')])[['step_index','option_id', 'attribute_id', 'value']]
# Out:
#      step_index option_id   attribute_id    value
# 13            2  coffee_a  price_dollars      $12
# 15            4  coffee_a    price_cents      .99
# 17            6  coffee_a      weight_oz  13.0 oz
# 19            8  coffee_b  price_dollars      $13
# 21           10  coffee_b      weight_oz  13.9 oz
# 76            2  coffee_a  price_dollars      $12
# 78            4  coffee_a    price_cents      .99
# 80            6  coffee_a      weight_oz  13.0 oz
# 82            8  coffee_b  price_dollars      $13
# 84           10  coffee_b    price_cents      .00
# 86           12  coffee_b      weight_oz  13.9 oz
# 103           2  coffee_a  price_dollars      $12
# 105           4  coffee_a    price_cents      .99
# 107           6  coffee_a      weight_oz  13.0 oz
# 109           8  coffee_b  price_dollars      $13
# 111          10  coffee_b      weight_oz  13.9 oz

# %%
13/12.99 # value
# Out:
# 1.0007698229407236

# %%
print('worst case',13.99/13.99) # worst case
print('best case', 13.99/13.00) # best case
# Out:
# worst case 1.0
# best case 1.0761538461538462

# %% [markdown]
# ### Verbal protocol analysis

# %%
df['provider'].value_counts()
# Out:
# provider
# google       472
# llamacpp     346
# mock         134
# anthropic     20
# Name: count, dtype: int64

# %%
has_reasoning  = df[(~df['reasoning'].isna()) & (df['reasoning']!='') & (df['provider']!='mock')]

has_reasoning['tc'] = has_reasoning['tool_calls'].apply(lambda l: l[0])
has_reasoning['t_name'] = has_reasoning['tc'].apply(lambda x: x.get('name'))
has_reasoning['t_option'] = has_reasoning['tc'].apply(lambda x: x.get('arguments').get('option_id'))
has_reasoning['t_attribute'] = has_reasoning['tc'].apply(lambda x: x.get('arguments').get('attribute_id'))

cue_lookup = {(c['option_id'], c['attribute_id']): c['value'] for c in config.get('cues', [])}
# Create the new value column by mapping over each row
has_reasoning['t_value'] = has_reasoning.apply(lambda row: cue_lookup.get((row['t_option'], row['t_attribute'])), axis=1)

has_reasoning[['t_name', 't_option', 't_attribute']].head()

has_reasoning[['reasoning', 'model_name']]['model_name'].value_counts()
# has_reasoning['reasoning']
# Out:
# model_name
# gemini-3.1-pro-preview                131
# gemini-3-flash-preview                105
# Qwen3.5-27B-UD-Q4_K_XL.gguf            86
# gemma-4-31B-it-UD-Q4_K_XL.gguf         52
# gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf     22
# Name: count, dtype: int64

# %%
has_reasoning[['t_name', 't_option', 't_attribute']]
# Out:
#             t_name  t_option          t_attribute
# 0     inspect_cell  coffee_a                price
# 2     inspect_cell  coffee_a            weight_oz
# 4     inspect_cell  coffee_b                price
# 6     inspect_cell  coffee_b            weight_oz
# 8     inspect_cell  coffee_a           list_price
# ..             ...       ...                  ...
# 942   inspect_cell  coffee_a            weight_oz
# 944   inspect_cell  coffee_b            weight_oz
# 946   inspect_cell  coffee_c            weight_oz
# 948   inspect_cell  coffee_a  discount_percentage
# 950  submit_choice  coffee_a                  NaN
#
# [396 rows x 3 columns]

# %%
# has_reasoning[['step_index', 't_name', 't_option', 't_attribute', 't_value']].tail(10)

# %%
has_reasoning_geminipro = has_reasoning[(has_reasoning['model_name']=='gemini-3.1-pro-preview')&(has_reasoning['budget_type']=='points')]
# has_reasoning_geminipro
# for i, row in (has_reasoning_geminipro[['step_index', 'model_name','budget_type', 'budget_max', 'reasoning', 't_name', 't_option', 't_attribute', 't_value']]).iterrows():
#     print(row.to_csv())
#     print('+'*50)

# %% [markdown]
# ### classify final reasoning

# %%
client = OpenAI(
    base_url='http://localhost:8080/v1',
    api_key="sk-no-key-required"
)
class ChoiceClassification(BaseModel):
    label: Literal["price per weight value", "discount"]

def classify_reasoning(reasoning_text: str) -> str:
    # Initialize the OpenAI client pointing to the local Llama Cpp server
    system_prompt = (
        "You are a highly precise data annotator analyzing the decision-making process of AI models. "
        "You will be provided with the reasoning an AI model gave for choosing a specific product. "
        "Your task is to identify the primary factor or attribute that drove the model's choice.\n\n"
        "Classify the reasoning into exactly one of two categories:\n"
        "1. 'price per weight value' (if the choice is based on unit price, weight-to-price ratio, or getting more product for the money)\n"
        "2. 'discount' (if the choice is based on a price reduction, sale, or percentage off the original retail price)\n\n"
        # "You must output only the exact category name and nothing else. Do not include any explanations or punctuation."
    )
    
    user_prompt = reasoning_text


    try:
        response = client.chat.completions.parse(
            model="gemma-4-31B-it-UD-Q4_K_XL.gguf", # The model name doesn't matter for the local llama.cpp server
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            response_format=ChoiceClassification,
        )
        
        # Extract and clean up the classification result
        # print(response.choices[0])
        category = response.choices[0].message.parsed
        return category.label
        
    except Exception as e:
        print(f"An error occurred: {e}")
        return "Error"

# %%
# sample = has_reasoning_submit_choice.iloc[0]['reasoning']
# print(sample)
# classification = classify_reasoning(sample)
# print(classification)

# %%
has_reasoning_submit_choice = has_reasoning[has_reasoning['t_name']=='submit_choice']
has_reasoning_submit_choice['class_choice'] = has_reasoning_submit_choice['reasoning'].apply(classify_reasoning)

# %%
has_reasoning_submit_choice.groupby('model_name')['class_choice'].value_counts()
# Out:
# model_name                          class_choice
# Qwen3.5-27B-UD-Q4_K_XL.gguf         discount                   5
#                                     price per weight value     4
# gemini-3-flash-preview              price per weight value     8
#                                     discount                   3
# gemini-3.1-pro-preview              price per weight value    15
#                                     discount                   7
# gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf  price per weight value     5
# gemma-4-31B-it-UD-Q4_K_XL.gguf      price per weight value     6
#                                     discount                   2
# Name: count, dtype: int64

# %%
has_reasoning[['step_index','reasoning', 't_name']]
# Out:
#      step_index                                          reasoning  \
# 0             1  **My Strategy for Coffee Selection**\n\nOkay, ...
# 2             3  Okay, here's my thought process on this:\n\n**...
# 4             5  Okay, here's my take on those thoughts, framed...
# 6             7  Okay, here's my take on those thoughts, framed...
# 8             9  Okay, here's my breakdown of this quick coffee...
# ..          ...                                                ...
# 942          11  **Analyzing the Sale Price Discrepancy**\n\nOk...
# 944          13  Okay, here's my interpretation of that thought...
# 946          15  Okay, here's my interpretation of that thought...
# 948          17  Okay, here's my take on those thoughts, framed...
# 950          19  **My Decision-Making Process**\n\nOkay, so `co...
#
#             t_name
# 0     inspect_cell
# 2     inspect_cell
# 4     inspect_cell
# 6     inspect_cell
# 8     inspect_cell
# ..             ...
# 942   inspect_cell
# 944   inspect_cell
# 946   inspect_cell
# 948   inspect_cell
# 950  submit_choice
#
# [396 rows x 3 columns]

# %% [markdown]
# # the effect of constraint on choice

# %% [markdown]
# ### Classify choice reasoning on attribute

# %%
client = OpenAI(
    base_url='http://localhost:8080/v1',
    api_key="sk-no-key-required"
)
attribute_list = [att['id'] for att in config['attributes']]

class AttributeClassification(BaseModel):
    label: Literal[*attribute_list]

def classify_choice_attribute(reasoning_text: str) -> str:
    # Initialize the OpenAI client pointing to the local Llama Cpp server
    attribute_string = ''
    for att in attribute_list:
        attribute_string+=f'- "{att}"\n'
    
    system_prompt = (
        "You are a highly precise data annotator analyzing the decision-making process of AI models. "
        "You will be provided with the reasoning an AI model gave for choosing a specific product. "
        "Your task is to identify the primary attribute that determined the model's final choice.\n\n"
        "Classify the reasoning into exactly one of these categories:\n"
        f'{attribute_string}'
    )
    
    user_prompt = reasoning_text

    try:
        response = client.chat.completions.parse(
            model="gemma-4-31B-it-UD-Q4_K_XL.gguf", # The model name doesn't matter for the local llama.cpp server
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            response_format=AttributeClassification,
        )
        
        # Extract and clean up the classification result
        # print(response.choices[0])
        category = response.choices[0].message.parsed
        return category.label
        
    except Exception as e:
        print(f"An error occurred: {e}")
        return "Error"

# %%
df['t_name'] = df['tool_calls'].apply(lambda l: l[0]['name'] if type(l)==list else None)
submit_choice = df[df['t_name']=='submit_choice']
submit_choice_reasoning = submit_choice[['budget_max','reasoning']].copy()
submit_choice_reasoning = submit_choice_reasoning.sort_values(by=['budget_max'], ascending=False)
sample = submit_choice_reasoning.iloc[0]
# print(sample['reasoning'])

# %%
submit_choice_reasoning['choice_attribute'] = None
for i, row in submit_choice_reasoning.iterrows():
    choice_attribute = classify_choice_attribute(row['reasoning'])
    submit_choice_reasoning.at[i, 'choice_attribute'] = choice_attribute
    print(row['budget_max'], choice_attribute)
# Out:
# 20 weight_oz
# 20 weight_oz
# 20 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 weight_oz
# 10 discount_percentage
# 10 discount_percentage
# 10 weight_oz
# 10 weight_oz
# 5 weight_oz
# 5 sale_price
# 5 discount_percentage
# 5 sale_price
# 5 sale_price
# 5 sale_price
# 5 weight_oz
# 5 discount_percentage
# 5 discount_percentage
# 5 weight_oz
# 5 discount_percentage
# 5 discount_percentage
# 1 list_price
# 1 list_price
# 1 sale_price
# 1 sale_price
# 1 discount_percentage
# 1 discount_percentage
# 1 list_price
# 1 sale_price
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage
# 1 discount_percentage

# %%
submit_choice_reasoning
# Out:
#      budget_max                                          reasoning  \
# 94           20  \nThe objective is to find the "best deal" on ...
# 134          20  \nThe objective is to find the best deal on co...
# 58           20  \nThe objective is to find the best deal on co...
# 156          10  \nThe user wants me to find the best deal on c...
# 326          10  \nThe user wants me to find the best deal on c...
# 348          10  \nThe user wants the best deal on coffee.\nI h...
# 304          10  \nThe goal is to find the best deal on coffee....
# 282          10  \nThe user wants to find the best deal on coff...
# 238          10  \nThe goal is to find the best deal on coffee....
# 260          10  \nThe user wants to find the best deal on coff...
# 204          10  \nAll options have the same sale price of $12....
# 216          10  \nAll five options have the same `sale_price` ...
# 504          10  \nThe goal is to find the best deal on coffee,...
# 526          10  \nThe goal is to find the best deal on coffee ...
# 424           5  \nThe goal is to find the best deal.\n"Best de...
# 436           5  \nAll options have the same sale price of $12....
# 460           5  \nThe user wants me to find the best deal on c...
# 390           5  \nAll the options I've checked so far (option_...
# 358           5  \nAll options I've checked (1, 3, 4, 2) have a...
# 168           5  \nAll options have the same sale price ($12.60...
# 448           5  \nThe goal is to find the best deal on coffee....
# 414           5  \nAll options have the same sale price of $12....
# 380           5  \nAll options inspected so far (option_2, opti...
# 192           5  \nThe goal is to find the "best deal" on coffe...
# 402           5  \nAll sale prices are $12.60. Since they are a...
# 370           5  \nThe user wants me to find the best deal on c...
# 10            1  \nThe user wants me to find the best deal on c...
# 6             1  \nThe user wants to find the best deal on coff...
# 176           1  \nThe user wants me to find the best deal on c...
# 172           1  \nThe user wants me to find the best deal on c...
# 18            1  \nThe user wants me to find the best coffee de...
# 14            1  \nThe user wants me to find the best deal on c...
# 2             1  \nThe user wants me to find the best deal on c...
# 180           1  \nI have checked the `sale_price` for `option_...
# 462           1  \nThe goal is to find the best deal on coffee ...
# 464           1  \nThe objective is to find the "best deal" on ...
# 468           1  \nThe goal is to find the "best deal" on coffe...
# 466           1  \nThe goal is to find the "best deal" on coffe...
# 472           1  \nThe user wants the best deal on coffee.\nLoo...
# 474           1  \nThe user wants me to find the "best deal" on...
# 478           1  \nThe goal is to find the best deal on coffee ...
# 476           1  \nThe objective is to find the best deal on co...
# 482           1  \nThe objective is to find the "best deal" on ...
# 480           1  \nThe user wants me to find the "best deal" on...
#
#         choice_attribute
# 94             weight_oz
# 134            weight_oz
# 58             weight_oz
# 156            weight_oz
# 326            weight_oz
# 348            weight_oz
# 304            weight_oz
# 282            weight_oz
# 238            weight_oz
# 260            weight_oz
# 204  discount_percentage
# 216  discount_percentage
# 504            weight_oz
# 526            weight_oz
# 424            weight_oz
# 436           sale_price
# 460  discount_percentage
# 390           sale_price
# 358           sale_price
# 168           sale_price
# 448            weight_oz
# 414  discount_percentage
# 380  discount_percentage
# 192            weight_oz
# 402  discount_percentage
# 370  discount_percentage
# 10            list_price
# 6             list_price
# 176           sale_price
# 172           sale_price
# 18   discount_percentage
# 14   discount_percentage
# 2             list_price
# 180           sale_price
# 462  discount_percentage
# 464  discount_percentage
# 468  discount_percentage
# 466  discount_percentage
# 472  discount_percentage
# 474  discount_percentage
# 478  discount_percentage
# 476  discount_percentage
# 482  discount_percentage
# 480  discount_percentage

# %%
# 1. Create a cross-tabulation and normalize it so each row sums to 1.0 (100%)
crosstab = pd.crosstab(
    submit_choice_reasoning['budget_max'], 
    submit_choice_reasoning['choice_attribute'], 
    normalize='index' # This gives you percentages instead of raw counts
)

# 2. Plot as a stacked bar chart
ax = crosstab.plot(kind='bar', stacked=True, figsize=(10, 6), )

plt.title('Reasoning Strategy Proportions by Budget Constraint', fontsize=14)
plt.xlabel('Max Budget (budget_max)', fontsize=12)
plt.ylabel('Proportion of Responses', fontsize=12)

# Move the legend outside the plot so it doesn't cover the bars
plt.legend(title='Choice Attribute', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# 1. Get the raw counts
crosstab_counts = pd.crosstab(
    submit_choice_reasoning['budget_max'], 
    submit_choice_reasoning['choice_attribute']
)

# 2. Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(crosstab_counts, annot=True, fmt='d', cmap='Blues', cbar_kws={'label': 'Count'})

plt.title('Frequency of Choice Attributes by Budget', fontsize=14)
plt.ylabel('Max Budget (budget_max)', fontsize=12)
plt.xlabel('Choice Attribute', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Attributes checked

# %%
df, config = get_data(exp_name)
df.groupby(['budget_max'])['session_name'].nunique()
# Out:
# budget_max
# 1     18
# 5     12
# 10    19
# 20    19
# Name: session_name, dtype: int64

# %%
# 1. First, get the counts PER SESSION (using our clean code from earlier)
session_counts = (
    df.groupby(['session_name', 'budget_max'])['attribute_id']
    .value_counts()
    .unstack(fill_value=0)
    .reset_index()
)

# 2. Next, drop the session name, group by budget_max, and take the MEAN
# This gives the average number of each attribute called per session.
mean_searches_per_session = session_counts.drop(columns=['session_name']).groupby('budget_max').mean()

# 3. Plot as a Stacked Bar Chart
ax = mean_searches_per_session.plot(kind='bar', stacked=True, figsize=(12, 7), colormap='tab20')

plt.title('Average Attribute Searches Per Session by Budget', fontsize=15)
plt.xlabel('Max Budget (budget_max)', fontsize=12)
plt.ylabel('Average Number of Searches per Session', fontsize=12)
plt.legend(title='Attribute', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_summary = (
    df.groupby(['session_name', 'budget_max'])['attribute_id']
    .value_counts()
    .unstack(fill_value=0)
    .reset_index()
)
# 1. Using the df_summary from the previous step:
# Drop 'session_name' so we only have numbers, then group by budget and get the mean
mean_searches_per_budget = df_summary.drop(columns=['session_name']).groupby('budget_max').mean()
mean_searches_per_budget

# 2. Plot as a grouped bar chart (not stacked)
mean_searches_per_budget.plot(kind='bar', figsize=(12, 7), colormap='tab20')

plt.title('Average Number of Searches per Attribute by Budget Constraint', fontsize=15)
plt.xlabel('Max Budget (budget_max)', fontsize=12)
plt.ylabel('Average Searches per Session', fontsize=12)
plt.legend(title='Attribute', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Out:
# budget_max
# 1     18
# 5     12
# 10    19
# 20    15
# Name: session_name, dtype: int64
